# %% [markdown]
# <a href="https://colab.research.google.com/github/Lindon1972/Atividades-DIO/blob/main/DIO_Pandas1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
from types import CodeType
df = pd.read_excel("/content/drive/MyDrive/Datasets/PIB dos Municípios.xls")

# %%
df.head()
# Out:
#     Ano  Código da Grande Região Nome da Grande Região  \
# 0  2002                        1                 Norte
# 1  2002                        1                 Norte
# 2  2002                        1                 Norte
# 3  2002                        1                 Norte
# 4  2002                        1                 Norte
#
#    Código da Unidade da Federação Sigla da Unidade da Federação  \
# 0                              11                            RO
# 1                              11                            RO
# 2                              11                            RO
# 3                              11                            RO
# 4                              11                            RO
#
#   Nome da Unidade da Federação  Código do Município      Nome do Município  \
# 0                     Rondônia              1100015  Alta Floresta D'Oeste
# 1                     Rondônia              1100023              Ariquemes
# ...

# %%
df.shape
# Out:
# (44501, 40)

# %%
df.columns
# Out:
# Index(['Ano', 'Código da Grande Região', 'Nome da Grande Região',
#        'Código da Unidade da Federação', 'Sigla da Unidade da Federação',
#        'Nome da Unidade da Federação', 'Código do Município',
#        'Nome do Município', 'Região Metropolitana', 'Código da Mesorregião',
#        'Nome da Mesorregião', 'Código da Microrregião', 'Nome da Microrregião',
#        'Código da Região Geográfica Imediata',
#        'Nome da Região Geográfica Imediata',
#        'Município da Região Geográfica Imediata',
#        'Código da Região Geográfica Intermediária',
#        'Nome da Região Geográfica Intermediária',
#        'Município da Região Geográfica Intermediária',
#        'Código Concentração Urbana', 'Nome Concentração Urbana',
#        'Tipo Concentração Urbana', 'Código Arranjo Populacional',
#        'Nome Arranjo Populacional', 'Hierarquia Urbana',
#        'Hierarquia Urbana (principais categorias)', 'Código da Região Rural',
#        'Nome da Região Rural',
# ...

# %%
df.dtypes
# Out:
# Ano                                                                                                                                                       int64
# Código da Grande Região                                                                                                                                   int64
# Nome da Grande Região                                                                                                                                    object
# Código da Unidade da Federação                                                                                                                            int64
# Sigla da Unidade da Federação                                                                                                                            object
# Nome da Unidade da Federação                                                                                                                             object
# ...

# %%
df.tail(1)
# Out:
#         Ano  Código da Grande Região Nome da Grande Região  \
# 44500  2009                        5          Centro-oeste
#
#        Código da Unidade da Federação Sigla da Unidade da Federação  \
# 44500                              53                            DF
#
#       Nome da Unidade da Federação  Código do Município Nome do Município  \
# 44500             Distrito Federal              5300108          Brasília
#
#                                     Região Metropolitana  \
# 44500  Região Integrada de Desenvolvimento do Distrit...
#
#        Código da Mesorregião  ... Semiárido  Cidade-Região de São Paulo  \
# 44500                   5301  ...       Não                         Não
#
#       Valor adicionado bruto da Agropecuária, \na preços correntes\n(R$ 1.000)  \
# 44500                                         364899.931
#
#        Valor adicionado bruto da Indústria,\na preços correntes\n(R$ 1.000)  \
# 44500                                        7660050.614
#
# ...

# %%
df.describe()
# Out:
#                 Ano  Código da Grande Região  Código da Unidade da Federação  \
# count  44501.000000             44501.000000                    44501.000000
# mean    2005.500753                 2.896991                       32.370958
# std        2.291250                 1.087393                        9.826607
# min     2002.000000                 1.000000                       11.000000
# 25%     2004.000000                 2.000000                       25.000000
# 50%     2006.000000                 3.000000                       31.000000
# 75%     2008.000000                 4.000000                       41.000000
# max     2009.000000                 5.000000                       53.000000
#
#        Código do Município  Código da Mesorregião  Código da Microrregião  \
# count         4.450100e+04           44501.000000            44501.000000
# mean          3.252921e+06            3241.362351            32388.601762
# ...

# %%
df["Nome da Grande Região"].unique()
# Out:
# array(['Norte', 'Nordeste', 'Sudeste', 'Sul', 'Centro-oeste'],
#       dtype=object)

# %%
fies = df.loc[df["Nome da Grande Região"]=='Norte']

# %%
fies.head()
# Out:
#     Ano  Código da Grande Região Nome da Grande Região  \
# 0  2002                        1                 Norte
# 1  2002                        1                 Norte
# 2  2002                        1                 Norte
# 3  2002                        1                 Norte
# 4  2002                        1                 Norte
#
#    Código da Unidade da Federação Sigla da Unidade da Federação  \
# 0                              11                            RO
# 1                              11                            RO
# 2                              11                            RO
# 3                              11                            RO
# 4                              11                            RO
#
#   Nome da Unidade da Federação  Código do Município      Nome do Município  \
# 0                     Rondônia              1100015  Alta Floresta D'Oeste
# 1                     Rondônia              1100023              Ariquemes
# ...

# %%
df.groupby("Nome da Grande Região")["Nome da Unidade da Federação"].nunique()
# Out:
# Nome da Grande Região
# Centro-oeste    4
# Nordeste        9
# Norte           7
# Sudeste         4
# Sul             3
# Name: Nome da Unidade da Federação, dtype: int64

# %%
df.rename(columns={"Produto Interno Bruto, \na preços correntes\n(R$ 1.000)":"PIB"}, inplace=True)
pd.options.display.float_format = '{:.2f}'.format
df.groupby("Nome da Grande Região")["PIB"].mean()*1000
# Out:
# Nome da Grande Região
# Centro-oeste   448269170.70
# Nordeste       172942715.54
# Norte          260278794.58
# Sudeste        807538319.96
# Sul            320860526.97
# Name: PIB, dtype: float64

# %%
df["PIB"].mean()*1000
# Out:
# 424880984.5176287

# %%
df["PIB"].sum()*1000
# Out:
# 18907628692018.996
